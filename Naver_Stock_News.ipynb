# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import matplotlib.pyplot as plt
from mpl_finance import candlestick2_ohlc
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import pandas as pd
from pandas_datareader import data  
from datetime import datetime
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\vxpko\anaconda3\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
def crawl_news_all(n):
    driver = webdriver.Chrome("C:\/chromedriver.exe")
    stock=[]
    driver.get('https://m.stock.naver.com/index.html#/domestic/capitalization/KOSPI')
    for i in range(1,11):

        #각 회사 들어가기
        driver.find_element_by_xpath('//*[@id="content"]/div[4]/div[2]/div[2]/div[1]/table/tbody/tr[{}]'.format(i)).click()
        time.sleep(1)

        #뉴스항목 들어가기
        driver.find_element_by_xpath('//*[@id="common_component_tab"]/div/ul/li[3]/a/span').click()
        time.sleep(1)

        # 뉴스 클릭
        for i in range(3):
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(1)
        for i in range(1,61):

            time.sleep(3)
            news=[]

            try:
                driver.find_element_by_xpath('//*[@id="content"]/div[4]/div[3]/div[2]/div/div[4]/ul/li[{}]/a'.format(i)).click()
            except:
                print("Pass")
                continue

            time.sleep(2)

            news.append(driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/div[1]/span[1]').text[:6])
            news.append(driver.find_element_by_xpath('//*[@id="content"]/div[2]/div[1]/div[1]/span[2]').text)
            news.append(driver.find_element_by_xpath('//*[@id="content"]/div[4]/div[3]/div[2]/div/div[1]/div[1]/div[1]/time').text[:10])
            news.append(driver.find_element_by_xpath('//*[@id="content"]/div[4]/div[3]/div[2]/div/div[1]/div[1]/strong').text)
            news.append(driver.find_element_by_xpath('//*[@id="content"]/div[4]/div[3]/div[2]/div/div[1]/div[2]/div[1]').text)

            time.sleep(2)
            driver.back()
            time.sleep(2)
            stock.append(news)

        driver.back()
        time.sleep(2)
        driver.back()
        time.sleep(2)

    col=['code','name','date','subject','content']
    df = pd.DataFrame(stock,columns=col)
    df.to_csv("./news.csv", mode='a',header=True,index=False)
    
    return df

# %%
crawl_news_all(11)
# Out:
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
# Pass
#        code  name        date                                     subject  \
# 0    005930  삼성전자  2021.07.17              [단독] 삼성 대미 반도체 투자 결국 6개월~1년 지연
# 1    005930  삼성전자  2021.07.16             인텔, '파운드리' 공격 투자 지속..삼성전자도 '경계'
# 2    005930  삼성전자  2021.07.16   TSMC, 삼성과 격차 더 벌리는데...총수 장기 부재로 전략적 결단 실종
# 3    005930  삼성전자  2021.07.16          "기업가치 10조 잠재력 있다" 삼성 600억 투자한 회사는?
# 4    005930  삼성전자  2021.07.16           "삼성, 美 제2파운드리 부지로 텍사스 중부 검토" -로이터
# ..      ...   ...         ...                                         ...
# 504  068270  셀트리온  2021.06.14                      엎치락뒤치락 코스피…셀트리온 3형제 강세
# 505  068270  셀트리온  2021.06.14        셀트리온 "코로나19 치료제 렉키로나, 3상서 효능 안전성 입증"
# 506  068270  셀트리온  2021.06.14         [속보]셀트리온 '렉키로나' 글로벌 임상 3상 효능·안전성 입증
# 507  068270  셀트리온  2021.06.14         [속보]셀트리온 “렉키로나주, 중증환자 발생률 70% 감소시켜”
# 508  068270  셀트리온  2021.06.12  [외인이 담은 바이오] 외국인 ‘셀트리온’ 기관투자자 ‘SK바이오팜’ 러브콜
#
#                                                content
# 0    텍사스 제2후보지역 착공 내년 1Q\n제1후보지서는 올해 2Q 공사 목표\n상업가동...
# 1    "인텔, 글로벌파운드리 인수 협상 진행 중"\n인수대금 약 34조 추정..인텔 역사...
# 2    [샌드위치 신세된 삼성]\nTSMC 2분기 영업익 6조 육박\n후발주자 추격 멀찍이...
# 3    인게임 앱 제작 지원 업체\n메타버스 생태계 활용성 주목\n\n삼성전자의 투자 자회...
# 4    미국 텍사스주 오스틴에 있는 삼성전자 팹 공장/사진=삼성전자 홈페이지\n삼성전자가 ...
# ..                                                 ...
# 504  셀트리온 장 초반 4%대 상승\n코스닥 상승 출발\n[이미지출처=연합뉴스]\n\n\...
# 505  셀트리온 코로나 치료제 임상 3상서 중증 악화율 70% 이상 감소.[사진 = 연합]...
# 506  [머니투데이 안정준 기자] 셀트리온은 코로나19 항체 치료제 '렉키로나'의 글로벌 ...
# 507  “고위험군 환자 대상으로는 72% 감소”\n[이데일리 왕해나 기자] 셀트리온(068...
# 508  셀트리온, 바이오에서 케미컬까지 장악 시작\nSK바이오팜 美영업 정상화 신약 판매 ...
#
# [509 rows x 5 columns]

# %%
n=pd.read_csv('./news.csv')

# %%
n
# Out:
#      005930  삼성전자  2021.07.16            코스피, 기관·외국인 매도에 하락 마감…삼성전자 도로 '7만전자'  \
# 0      5930  삼성전자  2021.07.16                     삼성, 쾌적한 여름 나기 위한 에어컨 선택법 공개
# 1      5930  삼성전자  2021.07.16              와이아이케이, 삼성전자에 187억원 규모 반도체 검사장비 공급
# 2      5930  삼성전자  2021.07.16               로이터 “삼성전자, 미국 제2파운드리 부지로 텍사스주 검토”
# 3      5930  삼성전자  2021.07.16              34조원 인텔 파운드리 쇼크…TSMC 삼성 모두 주가 급락했다
# 4      5930  삼성전자  2021.07.16                   TSMC 추격 바쁜 삼성 파운드리…인텔에 꼬리 잡히나
# ..      ...   ...         ...                                             ...
# 401   68270  셀트리온  2021.06.14             [속보]셀트리온 '렉키로나' 글로벌 임상 3상 효능·안전성 입증
# 402   68270  셀트리온  2021.06.14             [속보]셀트리온 “렉키로나주, 중증환자 발생률 70% 감소시켜”
# 403   68270  셀트리온  2021.06.12      [외인이 담은 바이오] 외국인 ‘셀트리온’ 기관투자자 ‘SK바이오팜’ 러브콜
# 404   68270  셀트리온  2021.06.12  [제약 바이오 이모저모] 셀트리온, 英기업 530억원 지분투자…"ADC 신약 확보"
# 405   68270  셀트리온  2021.06.11         셀트리온 "3분기 남아공발 변이 코로나19 바이러스 치료제 임상 진입"
#
#     사진=연합뉴스\n\n\n코스피가 기관과 외국인의 매도에 하락 마감했다. 신종 코로나바이러스 감염증(코로나19) 재확산 우려, 미국의 제조업 지표 둔화의 영향이다.\n\n특히 간밤 뉴욕증시에서 필라델피아 반도체 지수가 2% 넘게 급락한 영향으로, 우리 증시의 반도체 관련주들도 약세를 보이면서 전일 8만원대를 회복했던 삼성전자는 다시 7만원대로 내려앉았다.\n\n그나마 의약품 업종이 강하게 상승하며 오후 장에서 낙폭을 줄인 게 위안거리다.\n\n16일 코스피는 전일 대비 9.31포인트(0.28%) 내린 3276.91에 거래를 마쳤다.\n\n이날 코스피는 전장보다 0.10% 낮은 3282.89로 거래를 시작해 오전에는 3259.32까지 빠지기도 했지만, 오후 2시께부터 낙폭을 줄였다.\n\n서상영 미래에셋증권 연구원은 “달러와 엔화의 강세, 국채금리와 국제유가의 하락 등 위험자산 선호 심리가 위축된 여파로 외국인의 현·선물 순매도가 유입된 점이 부담이었다”며 “특히 인플레이션과 관련한 제롬 파월 연방준비제도(Fed) 의장과 백악관의 톤이 조금은 우려를 표명하는 등 바뀐 점은 전반적인 투자 심리를 위축시켰다”고 설명했다.\n\n다만 “주요 기업들의 실적 발표를 앞두고 있어 낙폭이 크게 확대되지는 않는 경향을 보였다”고 덧붙였다.\n\n이날 코스피에서 개인은 6935억원 어치 주식을 순매수한 반면, 기관과 외국인은 각각 5719억원 어치와 912억원 어치를 팔았다. 특히 외국인은 코스피200 선물도 6891계약을 순매도했다. 프로그램 매매는 555억원 매수 우위였다.\n\n주요 업종은 혼조세였다. 섬유·의복, 기계, 철강·금속, 전기·전자, 운송장비 등은 비교적 크게 하락했다. 반면 의약품, 종이·목재, 은행, 의료정밀 등은 올랐다.\n\n특히 의약품 업종은 장 후반에 셀트리온의 코로나19 항체치료제 렉키로나가 동물실험에서 델타 변이 바이러스에 대해 효과를 보였다는 소식이 전해지면서 상승세가 더 강해졌다. 장 전반에는 삼성바이오로직스가 강하게 오르며 의약품 업종 지수를 이끌었다.\n\n시가총액 상위 종목 중에서는 LG화학과 LG생활건강도 비교적 강한 상승세를 보였다.\n\n이를 제외한 시총 상위 종목들은 모두 내렸다. 특히 SK하이닉스, 카카오, 포스코(POSCO), 키아, 삼성전자, 현대모비스 등의 낙폭이 컸다. 삼성전자는 이날 7만9800원으로 마감돼 전일 탈환했던 ‘8만전자’가 다시 깨졌다.\n\n이날 유가증권시장에 상장된 에스디바이오센서는 공모가 대비 9000원(17.31%) 오른 6만1000원을 기록해 무난한 데뷔전을 치렀다.\n\n코스닥은 전일 대비 2.33포인트(0.22%) 내린 1051.98에 마감됐다. 이 시장에서는 개인이 1265억원 어치를 사들인 반면, 기관과 외국인은 각각 982억원 어치와 184억원 어치를 순매도했다.\n코스닥 시가총액 상위 종목들은 대체로 상승했다. 특히 카카오게임즈가 6% 넘게 올랐으며, 휴젤, 펄어비스, 셀트리온헬스케어도 비교적 강한 모습이었다. 반면 씨젠은 6% 넘게 빠졌고, 에이치엘비, 리노공업 등도 하락했다.\n\n이날 서울외환시장에서 원·달러 환율은 전일 대비 2원(0.18%) 내린 1139.50원에 거래를 마쳤다.
# 0    사진제공=삼성전자\n장마가 물러가자 본격적인 무더위가 시작됐다. 35도를 웃도는 기...
# 1    [이데일리 김연지 기자] 와이아이케이(232140)는 삼성전자(005930)와 반도...
# 2    사진=연합뉴스\n\n\n[헤럴드경제=양대근 기자] 삼성전자가 미국 내 두 번째 반도...
# 3    인텔의 파운드리 인수 움직임에\n한국 에이디칩스 주가 22%↑\n삼성전자·SK하이닉...
# 4    [인텔, 시장 3위 '글로벌파운드리' 인수 추진]\n\n\n'반도체 제왕' 인텔이 ...
# ..                                                 ...
# 401  [머니투데이 안정준 기자] 셀트리온은 코로나19 항체 치료제 '렉키로나'의 글로벌 ...
# 402  “고위험군 환자 대상으로는 72% 감소”\n[이데일리 왕해나 기자] 셀트리온(068...
# 403  셀트리온, 바이오에서 케미컬까지 장악 시작\nSK바이오팜 美영업 정상화 신약 판매 ...
# 404  [이데일리 노희준 기자] 한 주(6월7일~6월11일) 제약·바이오업계에서 주목받은 ...
# 405  기존 확보한 후보항체 중 32번 활용\n남아공·영국 변이주에 중화능력 확인\n\n[...
#
# [406 rows x 5 columns]
